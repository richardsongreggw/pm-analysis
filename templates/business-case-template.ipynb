# %% [markdown]
# # Business Case: [Project Name]
#
# **Date:** [Date]
#
# **Analyst:** [Your Name]
#
# ## Executive Summary
#
# [Brief overview of the business case]

# %% [markdown]
# ## 1. Problem Statement
#
# [Describe the problem or opportunity]

# %% [markdown]
# ## 2. Data Setup

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## 3. Market Analysis
#
# [Market size, trends, competition]

# %%
# Load and analyze market data
# df = pd.read_csv('../data/raw/market_data.csv')

# %% [markdown]
# ## 4. Financial Analysis

# %%
# Cost-benefit analysis
# Example:
development_cost = 100000
annual_revenue = 150000
annual_costs = 30000

roi = ((annual_revenue - annual_costs - development_cost) / development_cost) * 100
print(f'ROI: {roi:.1f}%')

# %% [markdown]
# ## 5. Recommendations
#
# [Your recommendation and next steps]
